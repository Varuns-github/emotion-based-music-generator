# %%
# !wget https://files.de-1.osf.io/v1/resources/p6vkg/providers/osfstorage/5bc9a904ccdb6b0019abaf62?action=download&direct&version=1
# Out:
# /bin/bash: direct: command not found
# --2022-06-21 10:23:48--  https://files.de-1.osf.io/v1/resources/p6vkg/providers/osfstorage/5bc9a904ccdb6b0019abaf62?action=download
# Resolving files.de-1.osf.io (files.de-1.osf.io)... 35.186.249.111
# Connecting to files.de-1.osf.io (files.de-1.osf.io)|35.186.249.111|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip 5bc9a904ccdb6b0019abaf62?action=download
# Out:
# Archive:  5bc9a904ccdb6b0019abaf62?action=download
#    creating: Set1/
#   inflating: Set1/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/Set1/
#   inflating: __MACOSX/Set1/._.DS_Store
#   inflating: Set1/001.mp3
#   inflating: __MACOSX/Set1/._001.mp3
#   inflating: Set1/002.mp3
#   inflating: __MACOSX/Set1/._002.mp3
#   inflating: Set1/003.mp3
#   inflating: __MACOSX/Set1/._003.mp3
#   inflating: Set1/004.mp3
#   inflating: __MACOSX/Set1/._004.mp3
#   inflating: Set1/005.mp3
#   inflating: __MACOSX/Set1/._005.mp3
#   inflating: Set1/006.mp3
#   inflating: __MACOSX/Set1/._006.mp3
#   inflating: Set1/007.mp3
#   inflating: __MACOSX/Set1/._007.mp3
#   inflating: Set1/008.mp3
#   inflating: __MACOSX/Set1/._008.mp3
#   inflating: Set1/009.mp3
#   inflating: __MACOSX/Set1/._009.mp3
#   inflating: Set1/010.mp3
#   inflating: __MACOSX/Set1/._010.mp3
#   inflating: Set1/011.mp3
#   inflating: __MACOSX/Set1/._011.mp3
#   inflating: Set1/012.mp3
# ...

# %%
# !wget https://files.de-1.osf.io/v1/resources/p6vkg/providers/osfstorage/5cb59291399269001610201a?action=download&direct&version=1
# Out:
# /bin/bash: direct: command not found
# --2022-06-21 10:23:53--  https://files.de-1.osf.io/v1/resources/p6vkg/providers/osfstorage/5cb59291399269001610201a?action=download
# Resolving files.de-1.osf.io (files.de-1.osf.io)... 35.186.249.111
# Connecting to files.de-1.osf.io (files.de-1.osf.io)|35.186.249.111|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !mv 5cb59291399269001610201a?action=download set1_tracklist.csv

# %%
import pandas as pd

df = pd.read_csv('set1_tracklist.csv')

print(df)
# Out:
#      Nro    Emotion           Album name  Track      Min:Sec
# 0      1      Happy        Shallow Grave      6  02:02-02:17
# 1      2      Happy        The Rainmaker      2  01:54-02:07
# 2      3      Happy        The Rainmaker      3  02:55-03:13
# 3      4      Happy   Man of Galilee CD1      2  03:02-03:18
# 4      5      Happy  Shakespeare in Love      1  01:06-01:22
# ..   ...        ...                  ...    ...          ...
# 355  356  Low Tens.      Lethal weapon 3      7  03:54-04:13
# 356  357  Low Tens.              Dracula      4  00:55-01:09
# 357  358  Low Tens.          Angel Heart      8  00:39-00:55
# 358  359  Low Tens.               Batman     18  02:46-03:02
# 359  360  Low Tens.               Batman      9  00:57-01:16
#
# [360 rows x 5 columns]

# %%
# !rm -rf High Tender Tens. Val.

# %%
from pathlib import Path

for index, row in df.iterrows():
  folder_name = row["Emotion"].replace(' ', '').replace('.', '')

  if(not Path(folder_name).is_dir()):
    # !mkdir $folder_name
    

  file_name = str(row["Nro"]).zfill(3) + ".mp3"
  # !mv Set1/$file_name $folder_name/$file_name

# %%
# !pwd
# !mv /content/LowVal /content/Disgust
# !mv /content/LowTens /content/Neutral
# Out:
# /content
